# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../utils')
print(sys.path)
import numpy as np
from load_dataset import *
import os
# Out:
# ['/home/shiqi/code/Project4-power-grid/pca_koopman', '/home/shiqi/anaconda3/envs/torch/lib/python39.zip', '/home/shiqi/anaconda3/envs/torch/lib/python3.9', '/home/shiqi/anaconda3/envs/torch/lib/python3.9/lib-dynload', '', '/home/shiqi/anaconda3/envs/torch/lib/python3.9/site-packages', '../utils', '../utils', '../utils', '../utils', '../utils', '../utils']

# %%
import yaml

config_path = '/home/shiqi/code/Project4-power-grid/pca_koopman/outputs/experiment_3/config.yaml'
with open(config_path, 'r') as file:
    config = yaml.safe_load(file)

# %%
save_dir = config['save_dir']
train_data_dir = config['data_dir']
# test_data_dir = '/home/shiqi/code/model_combination_Argos/data_linear_1000_test'

train_loss = np.load(os.path.join(save_dir, 'train_losses.npy'))
test_loss = np.load(os.path.join(save_dir, 'test_losses.npy'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[117], line 5
#       2 train_data_dir = config['data_dir']
#       3 # test_data_dir = '/home/shiqi/code/model_combination_Argos/data_linear_1000_test'
# ----> 5 train_loss = np.load(os.path.join(save_dir, 'train_losses.npy'))
#       6 test_loss = np.load(os.path.join(save_dir, 'test_losses.npy'))
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/shiqi/code/Project4-power-grid/pca_koopman/outputs/experiment_3/train_losses.npy'

# %%
import matplotlib.pyplot as plt

# Plot the training and validation losses
plt.figure(figsize=(10,5))
plt.plot(train_loss, label='Training Loss')
plt.plot(test_loss, label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.show()

# %%
# model
import pca_koopman_dir as km
import torch

# Device
device = 'cpu'
print('Device:', device)

x_dataset_origin, u_dataset = load_dataset_from_files(config)
fs, order = 1, 5
cutoff = config['cutoff']
x_dataset = [None] * len(x_dataset_origin)
for i in range(len(x_dataset_origin)):
    x_dataset[i] = lowpass_filter(x_dataset_origin[i], cutoff, fs, order)
x_data = np.concatenate(x_dataset, axis=0)
u_data = np.concatenate(u_dataset, axis=0)
x_dim = np.shape(x_data)[1]
u_dim = np.shape(u_data)[1]
params = km.Params(x_dim=x_dim, u_dim=u_dim, config = config)
model = km.build_model_MatrixWithInputs(params, x_data, u_data)
model = model.to(device)
# Out:
# Device: cpu

# %%
# load dict
model.load_state_dict(torch.load(os.path.join(save_dir, 'model.pth'), map_location=device))
# Out:
# <All keys matched successfully>

# %%
window_size = np.shape(x_dataset[0])[0]
predict_num = 10
x_data_slices = cut_slides(x_data, window_size, predict_num)
u_data_slices = cut_slides(u_data, window_size, predict_num)

# %%
print(len(x_data_slices))
print(np.shape(x_data_slices[0]))
# Out:
# 39960
# (1, 10, 68)

# %%
import random
indices = list(range(len(x_data_slices)))
random.shuffle(indices)
sample_indices = indices[:500]
x_samples = [x_data_slices[i] for i in sample_indices]
u_samples = [u_data_slices[i] for i in sample_indices]
x_dataset = x_samples
u_dataset = u_samples
print(x_dataset[0].shape)
# Out:
# (1, 10, 68)

# %%
begin = 0
end = 10

x_dataset_pred = []
x_dataset_true = []
x_pca_dataset_pred = []
x_pca_dataset_true = []

i = 0

for x_data, u_data in zip(x_dataset, u_dataset):
    i+=1
    steps = end - begin   

    x_data = torch.tensor(x_data, dtype=torch.float32).to(device)
    u_data = torch.tensor(u_data, dtype=torch.float32).to(device)
    x_data = x_data.squeeze(0)
    u_data = u_data.squeeze(0)
    x_pred = torch.zeros_like(x_data).to(device)
    x_pred[0, :] = x_data[0, :]
    # print(x_data[0, :].shape)
    x0_pca = model.encode(x_data[0, :].reshape(1, -1))
    # print(x0_pca.shape)
    for step in range(1, steps):
        u = u_data[step-1, :].reshape(1, -1)
        # print(u.shape)
        x1_pca = model.pca_forward(x0_pca, u)
        x_pred[step, :] = model.pca_decode(x1_pca)
        x0_pca = x1_pca
    x_dataset_pred.append(x_pred.detach().cpu().numpy())
    x_dataset_true.append(x_data.detach().cpu().numpy())
    x_pca_true = model.minmax_layer_1.transform(x_data.detach())
    x_pca_true = model.pca_transformer.transform(x_pca_true)
    x_pca_pred = model.minmax_layer_1.transform(x_pred.detach())
    x_pca_pred = model.pca_transformer.transform(x_pca_pred)
    x_pca_dataset_true.append(x_pca_true)
    x_pca_dataset_pred.append(x_pca_pred)
    print("The {}th data is predicted".format(i))
# Out:
# The 1th data is predicted
# The 2th data is predicted
# The 3th data is predicted
# The 4th data is predicted
# The 5th data is predicted
# The 6th data is predicted
# The 7th data is predicted
# The 8th data is predicted
# The 9th data is predicted
# The 10th data is predicted
# The 11th data is predicted
# The 12th data is predicted
# The 13th data is predicted
# The 14th data is predicted
# The 15th data is predicted
# The 16th data is predicted
# The 17th data is predicted
# The 18th data is predicted
# The 19th data is predicted
# The 20th data is predicted
# The 21th data is predicted
# The 22th data is predicted
# The 23th data is predicted
# The 24th data is predicted
# The 25th data is predicted
# The 26th data is predicted
# The 27th data is predicted
# The 28th data is predicted
# The 29th data is predicted
# The 30th data is predicted
# The 31th data is predicted
# The 32th data is predicted
# The 33th data is predicted
# The 34th data is predicted
# The 35th data is predicted
# The 36th data is predicted
# The 37th data is predicted
# The 38th data is predicted
# The 39th data is predicted
# The 40th data is predicted
# The 41th data is predicted
# The 42th data is predicted
# The 43th data is predicted
# The 44th data is predicted
# The 45th data is predicted
# The 46th data is predicted
# The 47th data is predicted
# The 48th data is predicted
# The 49th data is predicted
# The 50th data is predicted
# The 51th data is predicted
# The 52th data is predicted
# The 53th data is predicted
# The 54th data is predicted
# The 55th data is predicted
# The 56th data is predicted
# The 57th data is predicted
# The 58th data is predicted
# The 59th data is predicted
# The 60th data is predicted
# The 61th data is predicted
# The 62th data is predicted
# The 63th data is predicted
# The 64th data is predicted
# The 65th data is predicted
# The 66th data is predicted
# The 67th data is predicted
# The 68th data is predicted
# The 69th data is predicted
# The 70th data is predicted
# The 71th data is predicted
# The 72th data is predicted
# The 73th data is predicted
# The 74th data is predicted
# The 75th data is predicted
# The 76th data is predicted
# The 77th data is predicted
# The 78th data is predicted
# The 79th data is predicted
# The 80th data is predicted
# The 81th data is predicted
# The 82th data is predicted
# The 83th data is predicted
# The 84th data is predicted
# The 85th data is predicted
# The 86th data is predicted
# The 87th data is predicted
# The 88th data is predicted
# The 89th data is predicted
# The 90th data is predicted
# The 91th data is predicted
# The 92th data is predicted
# The 93th data is predicted
# The 94th data is predicted
# The 95th data is predicted
# The 96th data is predicted
# The 97th data is predicted
# The 98th data is predicted
# The 99th data is predicted
# The 100th data is predicted
# The 101th data is predicted
# The 102th data is predicted
# The 103th data is predicted
# The 104th data is predicted
# The 105th data is predicted
# The 106th data is predicted
# The 107th data is predicted
# The 108th data is predicted
# The 109th data is predicted
# The 110th data is predicted
# The 111th data is predicted
# The 112th data is predicted
# The 113th data is predicted
# The 114th data is predicted
# The 115th data is predicted
# The 116th data is predicted
# The 117th data is predicted
# The 118th data is predicted
# The 119th data is predicted
# The 120th data is predicted
# The 121th data is predicted
# The 122th data is predicted
# The 123th data is predicted
# The 124th data is predicted
# The 125th data is predicted
# The 126th data is predicted
# The 127th data is predicted
# The 128th data is predicted
# The 129th data is predicted
# The 130th data is predicted
# The 131th data is predicted
# The 132th data is predicted
# The 133th data is predicted
# The 134th data is predicted
# The 135th data is predicted
# The 136th data is predicted
# The 137th data is predicted
# The 138th data is predicted
# The 139th data is predicted
# The 140th data is predicted
# The 141th data is predicted
# The 142th data is predicted
# The 143th data is predicted
# The 144th data is predicted
# The 145th data is predicted
# The 146th data is predicted
# The 147th data is predicted
# The 148th data is predicted
# The 149th data is predicted
# The 150th data is predicted
# The 151th data is predicted
# The 152th data is predicted
# The 153th data is predicted
# The 154th data is predicted
# The 155th data is predicted
# The 156th data is predicted
# The 157th data is predicted
# The 158th data is predicted
# The 159th data is predicted
# The 160th data is predicted
# The 161th data is predicted
# The 162th data is predicted
# The 163th data is predicted
# The 164th data is predicted
# The 165th data is predicted
# The 166th data is predicted
# The 167th data is predicted
# The 168th data is predicted
# The 169th data is predicted
# The 170th data is predicted
# The 171th data is predicted
# The 172th data is predicted
# The 173th data is predicted
# The 174th data is predicted
# The 175th data is predicted
# The 176th data is predicted
# The 177th data is predicted
# The 178th data is predicted
# The 179th data is predicted
# The 180th data is predicted
# The 181th data is predicted
# The 182th data is predicted
# The 183th data is predicted
# The 184th data is predicted
# The 185th data is predicted
# The 186th data is predicted
# The 187th data is predicted
# The 188th data is predicted
# The 189th data is predicted
# The 190th data is predicted
# The 191th data is predicted
# The 192th data is predicted
# The 193th data is predicted
# The 194th data is predicted
# The 195th data is predicted
# The 196th data is predicted
# The 197th data is predicted
# The 198th data is predicted
# The 199th data is predicted
# The 200th data is predicted
# The 201th data is predicted
# The 202th data is predicted
# The 203th data is predicted
# The 204th data is predicted
# The 205th data is predicted
# The 206th data is predicted
# The 207th data is predicted
# The 208th data is predicted
# The 209th data is predicted
# The 210th data is predicted
# The 211th data is predicted
# The 212th data is predicted
# The 213th data is predicted
# The 214th data is predicted
# The 215th data is predicted
# The 216th data is predicted
# The 217th data is predicted
# The 218th data is predicted
# The 219th data is predicted
# The 220th data is predicted
# The 221th data is predicted
# The 222th data is predicted
# The 223th data is predicted
# The 224th data is predicted
# The 225th data is predicted
# The 226th data is predicted
# The 227th data is predicted
# The 228th data is predicted
# The 229th data is predicted
# The 230th data is predicted
# The 231th data is predicted
# The 232th data is predicted
# The 233th data is predicted
# The 234th data is predicted
# The 235th data is predicted
# The 236th data is predicted
# The 237th data is predicted
# The 238th data is predicted
# The 239th data is predicted
# The 240th data is predicted
# The 241th data is predicted
# The 242th data is predicted
# The 243th data is predicted
# The 244th data is predicted
# The 245th data is predicted
# The 246th data is predicted
# The 247th data is predicted
# The 248th data is predicted
# The 249th data is predicted
# The 250th data is predicted
# The 251th data is predicted
# The 252th data is predicted
# The 253th data is predicted
# The 254th data is predicted
# The 255th data is predicted
# The 256th data is predicted
# The 257th data is predicted
# The 258th data is predicted
# The 259th data is predicted
# The 260th data is predicted
# The 261th data is predicted
# The 262th data is predicted
# The 263th data is predicted
# The 264th data is predicted
# The 265th data is predicted
# The 266th data is predicted
# The 267th data is predicted
# The 268th data is predicted
# The 269th data is predicted
# The 270th data is predicted
# The 271th data is predicted
# The 272th data is predicted
# The 273th data is predicted
# The 274th data is predicted
# The 275th data is predicted
# The 276th data is predicted
# The 277th data is predicted
# The 278th data is predicted
# The 279th data is predicted
# The 280th data is predicted
# The 281th data is predicted
# The 282th data is predicted
# The 283th data is predicted
# The 284th data is predicted
# The 285th data is predicted
# The 286th data is predicted
# The 287th data is predicted
# The 288th data is predicted
# The 289th data is predicted
# The 290th data is predicted
# The 291th data is predicted
# The 292th data is predicted
# The 293th data is predicted
# The 294th data is predicted
# The 295th data is predicted
# The 296th data is predicted
# The 297th data is predicted
# The 298th data is predicted
# The 299th data is predicted
# The 300th data is predicted
# The 301th data is predicted
# The 302th data is predicted
# The 303th data is predicted
# The 304th data is predicted
# The 305th data is predicted
# The 306th data is predicted
# The 307th data is predicted
# The 308th data is predicted
# The 309th data is predicted
# The 310th data is predicted
# The 311th data is predicted
# The 312th data is predicted
# The 313th data is predicted
# The 314th data is predicted
# The 315th data is predicted
# The 316th data is predicted
# The 317th data is predicted
# The 318th data is predicted
# The 319th data is predicted
# The 320th data is predicted
# The 321th data is predicted
# The 322th data is predicted
# The 323th data is predicted
# The 324th data is predicted
# The 325th data is predicted
# The 326th data is predicted
# The 327th data is predicted
# The 328th data is predicted
# The 329th data is predicted
# The 330th data is predicted
# The 331th data is predicted
# The 332th data is predicted
# The 333th data is predicted
# The 334th data is predicted
# The 335th data is predicted
# The 336th data is predicted
# The 337th data is predicted
# The 338th data is predicted
# The 339th data is predicted
# The 340th data is predicted
# The 341th data is predicted
# The 342th data is predicted
# The 343th data is predicted
# The 344th data is predicted
# The 345th data is predicted
# The 346th data is predicted
# The 347th data is predicted
# The 348th data is predicted
# The 349th data is predicted
# The 350th data is predicted
# The 351th data is predicted
# The 352th data is predicted
# The 353th data is predicted
# The 354th data is predicted
# The 355th data is predicted
# The 356th data is predicted
# The 357th data is predicted
# The 358th data is predicted
# The 359th data is predicted
# The 360th data is predicted
# The 361th data is predicted
# The 362th data is predicted
# The 363th data is predicted
# The 364th data is predicted
# The 365th data is predicted
# The 366th data is predicted
# The 367th data is predicted
# The 368th data is predicted
# The 369th data is predicted
# The 370th data is predicted
# The 371th data is predicted
# The 372th data is predicted
# The 373th data is predicted
# The 374th data is predicted
# The 375th data is predicted
# The 376th data is predicted
# The 377th data is predicted
# The 378th data is predicted
# The 379th data is predicted
# The 380th data is predicted
# The 381th data is predicted
# The 382th data is predicted
# The 383th data is predicted
# The 384th data is predicted
# The 385th data is predicted
# The 386th data is predicted
# The 387th data is predicted
# The 388th data is predicted
# The 389th data is predicted
# The 390th data is predicted
# The 391th data is predicted
# The 392th data is predicted
# The 393th data is predicted
# The 394th data is predicted
# The 395th data is predicted
# The 396th data is predicted
# The 397th data is predicted
# The 398th data is predicted
# The 399th data is predicted
# The 400th data is predicted
# The 401th data is predicted
# The 402th data is predicted
# The 403th data is predicted
# The 404th data is predicted
# The 405th data is predicted
# The 406th data is predicted
# The 407th data is predicted
# The 408th data is predicted
# The 409th data is predicted
# The 410th data is predicted
# The 411th data is predicted
# The 412th data is predicted
# The 413th data is predicted
# The 414th data is predicted
# The 415th data is predicted
# The 416th data is predicted
# The 417th data is predicted
# The 418th data is predicted
# The 419th data is predicted
# The 420th data is predicted
# The 421th data is predicted
# The 422th data is predicted
# The 423th data is predicted
# The 424th data is predicted
# The 425th data is predicted
# The 426th data is predicted
# The 427th data is predicted
# The 428th data is predicted
# The 429th data is predicted
# The 430th data is predicted
# The 431th data is predicted
# The 432th data is predicted
# The 433th data is predicted
# The 434th data is predicted
# The 435th data is predicted
# The 436th data is predicted
# The 437th data is predicted
# The 438th data is predicted
# The 439th data is predicted
# The 440th data is predicted
# The 441th data is predicted
# The 442th data is predicted
# The 443th data is predicted
# The 444th data is predicted
# The 445th data is predicted
# The 446th data is predicted
# The 447th data is predicted
# The 448th data is predicted
# The 449th data is predicted
# The 450th data is predicted
# The 451th data is predicted
# The 452th data is predicted
# The 453th data is predicted
# The 454th data is predicted
# The 455th data is predicted
# The 456th data is predicted
# The 457th data is predicted
# The 458th data is predicted
# The 459th data is predicted
# The 460th data is predicted
# The 461th data is predicted
# The 462th data is predicted
# The 463th data is predicted
# The 464th data is predicted
# The 465th data is predicted
# The 466th data is predicted
# The 467th data is predicted
# The 468th data is predicted
# The 469th data is predicted
# The 470th data is predicted
# The 471th data is predicted
# The 472th data is predicted
# The 473th data is predicted
# The 474th data is predicted
# The 475th data is predicted
# The 476th data is predicted
# The 477th data is predicted
# The 478th data is predicted
# The 479th data is predicted
# The 480th data is predicted
# The 481th data is predicted
# The 482th data is predicted
# The 483th data is predicted
# The 484th data is predicted
# The 485th data is predicted
# The 486th data is predicted
# The 487th data is predicted
# The 488th data is predicted
# The 489th data is predicted
# The 490th data is predicted
# The 491th data is predicted
# The 492th data is predicted
# The 493th data is predicted
# The 494th data is predicted
# The 495th data is predicted
# The 496th data is predicted
# The 497th data is predicted
# The 498th data is predicted
# The 499th data is predicted
# The 500th data is predicted

# %%
print(np.shape(x_pca_dataset_pred[0]))
# Out:
# torch.Size([10, 10])

# %%
errors = [x_dataset_true[i] - x_dataset_pred[i] for i in range(len(x_dataset_true))]
errors_pca = [x_pca_dataset_true[i] - x_pca_dataset_pred[i] for i in range(len(x_pca_dataset_true))]

cumulative_error_norms = [np.array([np.linalg.norm(errors[i][:j+1,:]) for j in range(errors[i].shape[0])]) for i in range(len(errors))]
cumulative_error_norms_pca = [np.array([np.linalg.norm(errors_pca[i][:j+1,:]) for j in range(errors_pca[i].shape[0])]) for i in range(len(errors_pca))]

data_norms = [np.linalg.norm(x_dataset_true[i]) for i in range(len(x_dataset_true))]

data_norms_pca = [np.linalg.norm(x_pca_dataset_true[i]) for i in range(len(x_pca_dataset_true))]

relative_errors = [cumulative_error_norms[i] / data_norms[i] for i in range(len(cumulative_error_norms))] 

mean_relative_errors = np.mean(relative_errors, axis=0)
std_relative_errors = np.std(relative_errors, axis=0)

# %%
import matplotlib.pyplot as plt
xx = range(1,11)

# Plot the relative error with error bars
plt.figure(figsize=(10, 6))
upper_bound = mean_relative_errors + std_relative_errors
lower_bound = mean_relative_errors - std_relative_errors

plt.plot(xx, mean_relative_errors[:len(xx)], '-', label='Mean Cumulative Error')
plt.fill_between(xx, lower_bound[:len(xx)], upper_bound[:len(xx)], color='gray', alpha=0.2)
plt.xlabel('Prediction Time Step')
plt.ylabel('Cumulative Error')
plt.title('Cumulative Error with Error Bars')
plt.grid(True)
plt.show()

# %%
errors_pca = [x_pca_dataset_pred[i] - x_pca_dataset_true[i] for i in range(len(x_pca_dataset_true))]

cumulative_error_norms_pca = []
for k in range(10):
    cur_dim_norm = np.array([np.array([np.linalg.norm(errors_pca[i][:j+1,k]) for j in range(errors_pca[i].shape[0])]) for i in range(len(errors_pca))])
    cumulative_error_norms_pca.append(cur_dim_norm)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming window_size, cumulative_error_norms_pca, x_data_pca_traj, and other variables are defined

fig, axs = plt.subplots(2, 5, figsize=(25, 10))  # Create a subplot layout with 2 rows and 5 columns

for dim in range(10):  # Adjust this range if you have more or fewer dimensions
    # Calculate mean and standard deviation of relative errors
    mean_relative_errors_pca = np.mean([
        cumulative_error_norms_pca[dim][i] / np.linalg.norm(x_pca_dataset_true[i]) 
        for i in range(len(cumulative_error_norms_pca[dim]))
    ], axis=0)
    std_relative_errors_pca = np.std([
        cumulative_error_norms_pca[dim][i] / np.linalg.norm(x_pca_dataset_true[i]) 
        for i in range(len(cumulative_error_norms_pca[dim]))
    ], axis=0)

    # Calculate error bounds
    upper_bound = mean_relative_errors_pca + std_relative_errors_pca
    lower_bound = mean_relative_errors_pca - std_relative_errors_pca

    x_axis = range(1, 11)
    # Determine the row and column for each subplot based on the dimension index
    row = dim // 5  # Determines the row by integer division
    col = dim % 5   # Determines the column by taking the remainder

    # Plot the mean cumulative error curve
    axs[row, col].plot(x_axis, mean_relative_errors_pca[:len(x_axis)], '-', label='Mean Cumulative Error')
    
    # Fill the area between bounds to indicate error range
    axs[row, col].fill_between(x_axis, lower_bound[:len(x_axis)], upper_bound[:len(x_axis)], color='gray', alpha=0.2)

    axs[row, col].set_xlabel('Prediction Time Step')
    axs[row, col].set_ylabel('Cumulative Error')
    axs[row, col].set_title(f'Dimension {dim}')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random


# Select random indices
random.seed(0)
ks = random.sample(range(len(x_dataset_true)), 5)

# Plot the true and predicted trajectories
fig, axs = plt.subplots(10, 5, figsize=(25, 40))

for i, k in enumerate(ks):
    x_true = x_pca_dataset_true[k]
    x_pred = x_pca_dataset_pred[k]

    for j in range(10):
        row = j
        col = i
        ax = axs[row, col]
        ax.plot(x_true[:, j], label='True')  # 绘制真实值
        ax.plot(x_pred[:, j], label='Pred')  # 绘制预测值
        ax.set_title(f'Sample {k}, Dim {j}')  # 设置标题
        ax.set_xlabel('Time')  # 设置x轴标签
        ax.set_ylabel('Value')  # 设置y轴标签
        ax.legend()  # 显示图例

plt.tight_layout()  # 调整布局
plt.show()  # 显示图形
